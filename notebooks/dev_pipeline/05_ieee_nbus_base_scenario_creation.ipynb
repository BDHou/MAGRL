# %%
# %load_ext autoreload
# %autoreload 2
import sys
import json
import os
import numpy as np
from collections import defaultdict
from pathlib import Path
project_root = Path(os.getcwd()).parent.parent
print(f'当前目录: {project_root}')
sys.path.append(str(project_root))
# Out:
# 当前目录: /Users/steven/Documents/GridProjects/MAGRL

# %% [markdown]
# 定义生成算例的时间跨度，基于的IEEE NBus算例和输出目录

# %%
days = 1
steps_per_day = 96
seed = 123
feeder = "case33bw"
out_dir = os.path.join(project_root, f"data/generated/ieee_{feeder}")

# %%
from scripts.generate_env_data import generate_ieee_env_data
from scenario.base_scenario import ScenarioConfig
cfg = ScenarioConfig(days=days)
generate_ieee_env_data(feeder, out_dir, cfg, seed)
# Out:
# Loading IEEE standard case: case33bw
# Topology configured: 33 buses, 35 loads (including 3 PVs as negative loads), 3 storages.
# Environment logic topology successfully explicitly saved to: /Users/steven/Documents/GridProjects/MAGRL/data/generated/ieee_case33bw/topology
# Data generation complete! Saved loads to: /Users/steven/Documents/GridProjects/MAGRL/data/generated/ieee_case33bw
#
# --- 数据分析摘要 ---
# >> 总用电负荷: 最大 = 3.29 MW, 最小 = 2.11 MW, 平均 = 2.59 MW
# >> 总光伏发电: 最大 = 5.58 MW, 最小 = 0.00 MW, 平均 = 1.66 MW
# >> 净负荷 (Load - Gen): 最大 = 3.29 MW, 最小 = -3.14 MW (如果是负值说明出现功率向主网红反灌倒送)
#
#  数据时序分析图已保存至: /Users/steven/Documents/GridProjects/MAGRL/data/generated/ieee_case33bw/total_power_curve.png

# %%
import pandapower as pp
import pandas as pd
net = pp.from_pickle(os.path.join(out_dir, 'topology.p'))
pp.runpp(net)
net.storage
# Out:
#             name  bus  p_mw  q_mvar  sn_mva  soc_percent  min_e_mwh  \
# 0  Storage_bus17   17   0.0     0.0     NaN          NaN        0.0
# 1  Storage_bus16   16   0.0     0.0     NaN          NaN        0.0
# 2  Storage_bus15   15   0.0     0.0     NaN          NaN        0.0
#
#    max_e_mwh  scaling  in_service  type  max_p_mw
# 0        4.0      1.0        True  None       1.0
# 1        4.0      1.0        True  None       1.0
# 2        4.0      1.0        True  None       1.0

# %%
net.res_bus
# Out:
#        vm_pu  va_degree      p_mw    q_mvar
# 0   1.000000   0.000000 -3.917677 -2.435141
# 1   0.997032   0.014481  0.100000  0.060000
# 2   0.982938   0.096042  0.090000  0.040000
# 3   0.975456   0.161651  0.120000  0.080000
# 4   0.968059   0.228285  0.060000  0.030000
# 5   0.949658   0.133853  0.060000  0.020000
# 6   0.946173  -0.096474  0.200000  0.100000
# 7   0.941328  -0.060403  0.200000  0.100000
# 8   0.935059  -0.133485  0.060000  0.020000
# 9   0.929244  -0.196014  0.060000  0.020000
# 10  0.928384  -0.188761  0.045000  0.030000
# 11  0.926885  -0.177269  0.060000  0.035000
# 12  0.920772  -0.268587  0.060000  0.035000
# 13  0.918505  -0.347268  0.120000  0.080000
# 14  0.917093  -0.384950  0.060000  0.010000
# 15  0.915725  -0.408205  0.060000  0.020000
# 16  0.913698  -0.485473  0.060000  0.020000
# 17  0.913090  -0.495063  0.090000  0.040000
# 18  0.996504   0.003651  0.090000  0.040000
# 19  0.992926  -0.063328  0.090000  0.040000
# 20  0.992222  -0.082686  0.090000  0.040000
# 21  0.991584  -0.103033  0.090000  0.040000
# 22  0.979352   0.065080  0.090000  0.050000
# 23  0.972681  -0.023654  0.420000  0.200000
# 24  0.969356  -0.067355  0.420000  0.200000
# 25  0.947729   0.173310  0.060000  0.025000
# 26  0.945165   0.229463  0.060000  0.025000
# 27  0.933726   0.312409  0.060000  0.020000
# 28  0.925507   0.390314  0.120000  0.070000
# 29  0.921950   0.495585  0.200000  0.600000
# 30  0.917789   0.411178  0.150000  0.070000
# 31  0.916873   0.388135  0.210000  0.100000
# 32  0.916590   0.380405  0.060000  0.040000
